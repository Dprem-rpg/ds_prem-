# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 906D-4371
#
#  Directory of C:\Users\Lenovo\DS_prem
#
# 27-07-2025  09:43    <DIR>          .
# 27-07-2025  09:43    <DIR>          ..
# 27-07-2025  04:08    <DIR>          .ipynb_checkpoints
# 27-07-2025  04:05            68,752 cleaned_feardata.csv
# 27-07-2025  09:41            68,752 clened_feardata.csv
# 27-07-2025  00:36            90,801 fear_greed_index.csv
# 27-07-2025  00:35        47,516,935 historical_data.csv
# 27-07-2025  09:43           394,400 notbook1.ipynb
# 27-07-2025  09:42            84,215 Untitled.ipynb
#                6 File(s)     48,223,855 bytes
#                3 Dir(s)  50,950,434,816 bytes free

# %%
df1=pd.read_csv('fear_greed_index.csv')

# %%
df1.head()
# Out:
#     timestamp  value classification        date
# 0  1517463000     30           Fear  2018-02-01
# 1  1517549400     15   Extreme Fear  2018-02-02
# 2  1517635800     40           Fear  2018-02-03
# 3  1517722200     24   Extreme Fear  2018-02-04
# 4  1517808600     11   Extreme Fear  2018-02-05

# %%
df1
# Out:
#        timestamp  value classification        date
# 0     1517463000     30           Fear  2018-02-01
# 1     1517549400     15   Extreme Fear  2018-02-02
# 2     1517635800     40           Fear  2018-02-03
# 3     1517722200     24   Extreme Fear  2018-02-04
# 4     1517808600     11   Extreme Fear  2018-02-05
# ...          ...    ...            ...         ...
# 2639  1745818200     54        Neutral  2025-04-28
# 2640  1745904600     60          Greed  2025-04-29
# 2641  1745991000     56          Greed  2025-04-30
# 2642  1746077400     53        Neutral  2025-05-01
# 2643  1746163800     67          Greed  2025-05-02
#
# [2644 rows x 4 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2644 entries, 0 to 2643
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       2644 non-null   int64
#  1   value           2644 non-null   int64
#  2   classification  2644 non-null   object
#  3   date            2644 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 82.8+ KB

# %%
df1.describe()
# Out:
#           timestamp        value
# count  2.644000e+03  2644.000000
# mean   1.631899e+09    46.981089
# std    6.597967e+07    21.827680
# min    1.517463e+09     5.000000
# 25%    1.574811e+09    28.000000
# 50%    1.631900e+09    46.000000
# 75%    1.688989e+09    66.000000
# max    1.746164e+09    95.000000

# %%
df1.isnull().sum()
# Out:
# timestamp         0
# value             0
# classification    0
# date              0
# dtype: int64

# %% [raw]
# Here their is no NULL value

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
#df1['date'] = pd.to_datetime(df1['timestamp'], unit='s')
df1['date'] = pd.to_datetime(df1['timestamp'], unit='s')
#df1.set_index('date', inplace=True)

# %%
df1.head()
# Out:
#     timestamp  value classification                date
# 0  1517463000     30           Fear 2018-02-01 05:30:00
# 1  1517549400     15   Extreme Fear 2018-02-02 05:30:00
# 2  1517635800     40           Fear 2018-02-03 05:30:00
# 3  1517722200     24   Extreme Fear 2018-02-04 05:30:00
# 4  1517808600     11   Extreme Fear 2018-02-05 05:30:00

# %%
df1.drop(['timestamp'],axis=1,inplace=True)

# %%
df1
# Out:
#       value classification                date
# 0        30           Fear 2018-02-01 05:30:00
# 1        15   Extreme Fear 2018-02-02 05:30:00
# 2        40           Fear 2018-02-03 05:30:00
# 3        24   Extreme Fear 2018-02-04 05:30:00
# 4        11   Extreme Fear 2018-02-05 05:30:00
# ...     ...            ...                 ...
# 2639     54        Neutral 2025-04-28 05:30:00
# 2640     60          Greed 2025-04-29 05:30:00
# 2641     56          Greed 2025-04-30 05:30:00
# 2642     53        Neutral 2025-05-01 05:30:00
# 2643     67          Greed 2025-05-02 05:30:00
#
# [2644 rows x 3 columns]

# %%
sns.histplot(x="classification",data=df1,kde=True)
# Out:
# <Axes: xlabel='classification', ylabel='Count'>

# %% [raw]
# 1)Most common sentiment: Fear (~780 days)
#
# 2)Least common: Extreme Greed

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
plt.plot(df1['date'], df1['value'], color='blue',marker='o', label='Fear & Greed Index')
plt.title('Fear & Greed Index Over Time')
plt.xlabel('Date')
plt.ylabel('Index Value')
plt.grid(True)
plt.legend()
plt.show()

# %% [raw]
# 1)These categories follow CNN Business's standard Fear & Greed Index scale, which reflects investor sentiment based on historical market data and psychological threshold
# 2)Major drops correspond to global events (e.g., early 2020 = COVID crash).

# %%
sns.barplot(x='classification',y='value',data=df1)
# Out:
# <Axes: xlabel='classification', ylabel='value'>

# %% [raw]
# A bivariate analysis of classification vs index value highlights a clear and interpretable trend. As the market sentiment shifts from Extreme Fear to Extreme Greed, the average index value increases steadily. This validates that:
#
# The classification thresholds (e.g. ≤25 as Extreme Fear, ≥75 as Extreme Greed) correctly group similar data points.
#
# The barplot acts as a visual validation of our data preprocessing logic

# %%
#Encoding 
df1.classification.unique()
# Out:
# array(['Fear', 'Extreme Fear', 'Neutral', 'Greed', 'Extreme Greed'],
#       dtype=object)

# %%
#we need to convert thisinto the numaric value using encoding
df1.classification.value_counts()
# Out:
# classification
# Fear             781
# Greed            633
# Extreme Fear     508
# Neutral          396
# Extreme Greed    326
# Name: count, dtype: int64

# %%
df1
# Out:
#       value classification                date
# 0        30           Fear 2018-02-01 05:30:00
# 1        15   Extreme Fear 2018-02-02 05:30:00
# 2        40           Fear 2018-02-03 05:30:00
# 3        24   Extreme Fear 2018-02-04 05:30:00
# 4        11   Extreme Fear 2018-02-05 05:30:00
# ...     ...            ...                 ...
# 2639     54        Neutral 2025-04-28 05:30:00
# 2640     60          Greed 2025-04-29 05:30:00
# 2641     56          Greed 2025-04-30 05:30:00
# 2642     53        Neutral 2025-05-01 05:30:00
# 2643     67          Greed 2025-05-02 05:30:00
#
# [2644 rows x 3 columns]

# %%
df1.loc[df1['classification']=='Fear','classification']=1
df1.loc[df1['classification']=='Extreme Fear','classification']=2
df1.loc[df1['classification']=='Neutral','classification']=3
df1.loc[df1['classification']=='Greed','classification']=4
df1.loc[df1['classification']=='Extreme Greed','classification']=5

# %%
#futher nex step is to split data to train a machine  
df1
# Out:
#       value classification                date
# 0        30              1 2018-02-01 05:30:00
# 1        15              2 2018-02-02 05:30:00
# 2        40              1 2018-02-03 05:30:00
# 3        24              2 2018-02-04 05:30:00
# 4        11              2 2018-02-05 05:30:00
# ...     ...            ...                 ...
# 2639     54              3 2025-04-28 05:30:00
# 2640     60              4 2025-04-29 05:30:00
# 2641     56              4 2025-04-30 05:30:00
# 2642     53              3 2025-05-01 05:30:00
# 2643     67              4 2025-05-02 05:30:00
#
# [2644 rows x 3 columns]

# %%
df1.to_csv('clened_feardata.csv',index=False)
